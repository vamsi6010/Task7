# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train_data = pd.read_csv('trainKNN.txt',sep=",",header=None)

# %%
train_data.columns =['Id','Rerfactive_Index','Sodium','Magnesium',
                                                         'Aluminium','Silicon','Potassium','Calsium',
                                                         'Barium','Iron',"Type_Glass"]

# %%
train_data.head(5)
# Out:
#    Id  Rerfactive_Index  Sodium  Magnesium  Aluminium  Silicon  Potassium  \
# 0   1           1.52101   13.64       4.49       1.10    71.78       0.06
# 1   2           1.51761   13.89       3.60       1.36    72.73       0.48
# 2   3           1.51618   13.53       3.55       1.54    72.99       0.39
# 3   4           1.51766   13.21       3.69       1.29    72.61       0.57
# 4   5           1.51742   13.27       3.62       1.24    73.08       0.55
#
#    Calsium  Barium  Iron  Type_Glass
# 0     8.75     0.0   0.0           1
# 1     7.83     0.0   0.0           1
# 2     7.78     0.0   0.0           1
# 3     8.22     0.0   0.0           1
# 4     8.07     0.0   0.0           1

# %%
test_data = pd.read_csv('testKNN.txt',sep=",",header=None)

# %%
test_data.columns =['Id','Rerfactive_Index','Sodium','Magnesium',
                                                         'Aluminium','Silicon','Potassium','Calsium',
                                                         'Barium','Iron',"Type_Glass"]

# %%
test_data.head(5)
# Out:
#     Id  Rerfactive_Index  Sodium  Magnesium  Aluminium  Silicon  Potassium  \
# 0   68           1.52152   13.05       3.65       0.87    72.32       0.19
# 1   69           1.52152   13.12       3.58       0.90    72.20       0.23
# 2   70           1.52300   13.31       3.58       0.82    71.99       0.12
# 3  144           1.51709   13.00       3.47       1.79    72.72       0.66
# 4  145           1.51660   12.99       3.18       1.23    72.97       0.58
#
#    Calsium  Barium  Iron  Type_Glass
# 0     9.85     0.0  0.17           1
# 1     9.82     0.0  0.16           1
# 2    10.17     0.0  0.03           1
# 3     8.18     0.0  0.00           2
# 4     8.81     0.0  0.24           2

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196 entries, 0 to 195
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                196 non-null    int64
#  1   Rerfactive_Index  196 non-null    float64
#  2   Sodium            196 non-null    float64
#  3   Magnesium         196 non-null    float64
#  4   Aluminium         196 non-null    float64
#  5   Silicon           196 non-null    float64
#  6   Potassium         196 non-null    float64
#  7   Calsium           196 non-null    float64
#  8   Barium            196 non-null    float64
#  9   Iron              196 non-null    float64
#  10  Type_Glass        196 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 17.0 KB

# %%
sns.pairplot(data=train_data)

# %%
train_data.describe()
# Out:
#                Id  Rerfactive_Index      Sodium   Magnesium   Aluminium  \
# count  196.000000        196.000000  196.000000  196.000000  196.000000
# mean   102.862245          1.518295   13.375204    2.758980    1.454337
# std     61.195663          0.003055    0.783145    1.392641    0.491688
# min      1.000000          1.511310   10.730000    0.000000    0.290000
# 25%     49.750000          1.516458   12.877500    2.362500    1.190000
# 50%    101.500000          1.517630   13.280000    3.480000    1.360000
# 75%    153.250000          1.518985   13.792500    3.610000    1.622500
# max    211.000000          1.533930   15.790000    4.490000    3.500000
#
#           Silicon   Potassium     Calsium      Barium        Iron  Type_Glass
# count  196.000000  196.000000  196.000000  196.000000  196.000000  196.000000
# mean    72.635408    0.519388    8.910714    0.164235    0.050255    2.668367
# std      0.763578    0.672703    1.421490    0.485198    0.086359    2.062416
# ...

# %%
for feat in train_data.columns:
    sns.boxplot(data=train_data[feat])
    plt.title(feat)
    plt.show()

# %%
cor = train_data.corr()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(cor,annot=True)

# %%
from sklearn.tree import ExtraTreeClassifier

# %%
exr = ExtraTreeClassifier()

# %%
exr.fit(train_data.iloc[:,0:9],train_data.iloc[:,10])
# Out:
# ExtraTreeClassifier()

# %%
exr.feature_importances_
# Out:
# array([0.4082095 , 0.04814794, 0.01972722, 0.20361062, 0.07807302,
#        0.02467721, 0.05983292, 0.13603533, 0.02168624])

# %%
from sklearn.preprocessing import StandardScaler

# %%
scr = StandardScaler()

# %%
x_train = train_data.iloc[:,0:9]
x_test = test_data.iloc[:,0:9]

# %%
y_train = train_data.iloc[:,10]
y_test = test_data.iloc[:,10]

# %%
x_train = pd.DataFrame(scr.fit_transform(x_train),columns=x_train.columns)

# %%
x_train.head()
# Out:
#          Id  Rerfactive_Index    Sodium  Magnesium  Aluminium   Silicon  \
# 0 -1.668796          0.890812  0.338985   1.246160  -0.722499 -1.123132
# 1 -1.652413         -0.224796  0.659028   0.605450  -0.192354  0.124197
# 2 -1.636031         -0.694007  0.198166   0.569455   0.174669  0.465571
# 3 -1.619648         -0.208390 -0.211490   0.670241  -0.335086 -0.033360
# 4 -1.603265         -0.287138 -0.134679   0.619848  -0.437037  0.583739
#
#    Potassium   Calsium    Barium
# 0  -0.684647 -0.113350 -0.339357
# 1  -0.058701 -0.762215 -0.339357
# 2  -0.192833 -0.797480 -0.339357
# 3   0.075430 -0.487153 -0.339357
# 4   0.045623 -0.592946 -0.339357

# %%
x_test = pd.DataFrame(scr.fit_transform(x_test),columns=x_test.columns)

# %%
x_test.head()
# Out:
#          Id  Rerfactive_Index    Sodium  Magnesium  Aluminium   Silicon  \
# 0 -2.004128          0.880895 -0.677453   1.044492  -0.835889 -0.576787
# 1 -1.981860          0.880895 -0.610974   1.003326  -0.782785 -0.715215
# 2 -1.959592          1.426641 -0.430531   1.003326  -0.924395 -0.957466
# 3 -0.311753         -0.752653 -0.724938   0.938638   0.792619 -0.115357
# 4 -0.289485         -0.933339 -0.734435   0.768095  -0.198647  0.173036
#
#    Potassium   Calsium    Barium
# 0  -0.247955  0.290297 -0.487942
# 1  -0.092714  0.267934 -0.487942
# 2  -0.519627  0.528829 -0.487942
# 3   1.576130 -0.954542 -0.487942
# 4   1.265648 -0.484932 -0.487942

# %%
x_train.drop('Id',axis=1,inplace=True)

# %%
x_test.drop('Id',axis=1,inplace=True)

# %%
x_train.head()
# Out:
#    Rerfactive_Index    Sodium  Magnesium  Aluminium   Silicon  Potassium  \
# 0          0.890812  0.338985   1.246160  -0.722499 -1.123132  -0.684647
# 1         -0.224796  0.659028   0.605450  -0.192354  0.124197  -0.058701
# 2         -0.694007  0.198166   0.569455   0.174669  0.465571  -0.192833
# 3         -0.208390 -0.211490   0.670241  -0.335086 -0.033360   0.075430
# 4         -0.287138 -0.134679   0.619848  -0.437037  0.583739   0.045623
#
#     Calsium    Barium
# 0 -0.113350 -0.339357
# 1 -0.762215 -0.339357
# 2 -0.797480 -0.339357
# 3 -0.487153 -0.339357
# 4 -0.592946 -0.339357

# %%
x_test.head()
# Out:
#    Rerfactive_Index    Sodium  Magnesium  Aluminium   Silicon  Potassium  \
# 0          0.880895 -0.677453   1.044492  -0.835889 -0.576787  -0.247955
# 1          0.880895 -0.610974   1.003326  -0.782785 -0.715215  -0.092714
# 2          1.426641 -0.430531   1.003326  -0.924395 -0.957466  -0.519627
# 3         -0.752653 -0.724938   0.938638   0.792619 -0.115357   1.576130
# 4         -0.933339 -0.734435   0.768095  -0.198647  0.173036   1.265648
#
#     Calsium    Barium
# 0  0.290297 -0.487942
# 1  0.267934 -0.487942
# 2  0.528829 -0.487942
# 3 -0.954542 -0.487942
# 4 -0.484932 -0.487942

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# usig p=2 and Mertic Minkowski means EUCLEDIAN distance
KNNCL = KNeighborsClassifier()

# %%
KNNCL.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
KNNCL.score(x_train,y_train)
# Out:
# 0.826530612244898

# %%
# Using Manhatten distance 
KNNCLM = KNeighborsClassifier(p=1)

# %%
KNNCLM.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(p=1)

# %%
KNNCLM.score(x_train,y_train)
# Out:
# 0.8112244897959183
